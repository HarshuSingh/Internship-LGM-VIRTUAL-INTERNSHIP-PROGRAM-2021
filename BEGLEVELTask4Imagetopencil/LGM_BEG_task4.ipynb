# %% [markdown]
# # LGM Internship - Lets Grow More
# ### Author: Harshit Singh
# ##  BEGINNER LEVEL TASK
# #### Task4 - VIP Data Science Task
# ##### Image to Pencil Sketch with Python

# %%
# importing libraries
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
# Read the image using pandas method read_csv
image=cv2.imread("/download.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F98416DA750>

# %% [markdown]
# ##### Now after reading the image, we will create a new image by converting the original image to greyscale:

# %%
gray_scale_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # converting image from RGB to GRAY scale image
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F98415FAE50>

# %% [markdown]
# ##### Now the next step is to invert the new grayscale image:

# %%
inverted_image = cv2.bitwise_not(gray_scale_image)  # using bitwise_not func to invert the image

cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F98415FA990>

# %% [markdown]
# ##### Now the next step in the process is to blur the image by using the Gaussian Function in OpenCV:

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
#We have used the gaussian blur technique with 21 x 21 pixel and the default sigma values filter on the image to smoothen our image.
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F984160C950>

# %% [markdown]
# ##### Then the final step is to invert the blurred image, then we can easily convert the image into a pencil sketch:

# %%
def pencil_sketch(x, y):
#dividing the greyscale value of the image by the inverse of blurred image value which highlights the boldest edges of an image
    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch=pencil_sketch(gray_scale_image,img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F9841620BD0>

# %% [markdown]
# ##### And finally, if we want to have a look at both the original image and the pencil sketch then here we can use the following commands:

# %%
cv2_imshow(image)

cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F984160C790>
# <PIL.Image.Image image mode=L size=300x168 at 0x7F984160C190>
